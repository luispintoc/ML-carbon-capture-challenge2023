# %%
from sklearnex import patch_sklearn
patch_sklearn()

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc, precision_recall_curve, average_precision_score, confusion_matrix
import xgboost as xgb
import numpy as np
import pickle
import shap
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (10,7)
plt.rcParams.update({'font.size': 15})
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# Read the train dataset from the CSV file
train_set = pd.read_csv('./data/train_df_expanded_KNN_imp_feats.csv')
# Replace infinite values with NaN
train_set = train_set.replace([np.inf, -np.inf], np.nan)

# %%
duplicates = train_set.columns[train_set.columns.duplicated(keep=False)]

# %%
# Extract the target variable from the dataset
y_train = train_set['Target > 2']
# Drop unnecessary columns and keep the feature matrix
x_train = train_set.drop(['Date', 'Target', 'Abs Target', 'Target > 2'], axis=1)

# %%
# Split the data into training, validation, and test sets using a 60-20-20 split
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.4, shuffle=False)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, shuffle=False)

# Drop the first 5 rows of validation set to avoid leakage from lagged features
X_val = X_val.iloc[5:]
y_val = y_val.iloc[5:]

# Create XGBoost DMatrix objects for training and validation data
dtrain = xgb.DMatrix(X_train, y_train)
dval = xgb.DMatrix(X_val, y_val)

# %%
# Define the hyperparameters for the XGBoost model
params = {'alpha': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'eta': 0.05, 'eval_metric': ['logloss'],
          'lambda': 1, 'max_depth': 4, 'objective': 'binary:logistic', 'scale_pos_weight': 1, 'subsample': 0.7, 'tree_method': 'exact',
          'nthread': -2}

# Train the XGBoost model
clf = xgb.train(params,dtrain,evals=[(dtrain, 'train'),(dval, 'test')],num_boost_round=300,verbose_eval=True,early_stopping_rounds=10)
# Out:
# [0]	train-logloss:0.64770	test-logloss:0.64691
# [1]	train-logloss:0.60654	test-logloss:0.60502
# [2]	train-logloss:0.56907	test-logloss:0.56695
# [3]	train-logloss:0.53484	test-logloss:0.53242
# [4]	train-logloss:0.50361	test-logloss:0.50062
# [5]	train-logloss:0.47486	test-logloss:0.47141
# [6]	train-logloss:0.44835	test-logloss:0.44453
# [7]	train-logloss:0.42380	test-logloss:0.41940
# [8]	train-logloss:0.40117	test-logloss:0.39640
# [9]	train-logloss:0.38010	test-logloss:0.37520
# [10]	train-logloss:0.36051	test-logloss:0.35524
# [11]	train-logloss:0.34240	test-logloss:0.33668
# [12]	train-logloss:0.32545	test-logloss:0.31934
# [13]	train-logloss:0.30957	test-logloss:0.30310
# [14]	train-logloss:0.29470	test-logloss:0.28803
# [15]	train-logloss:0.28076	test-logloss:0.27383
# [16]	train-logloss:0.26787	test-logloss:0.26066
# [17]	train-logloss:0.25561	test-logloss:0.24816
# [18]	train-logloss:0.24419	test-logloss:0.23649
# [19]	train-logloss:0.23344	test-logloss:0.22551
# [20]	train-logloss:0.22342	test-logloss:0.21524
# [21]	train-logloss:0.21398	test-logloss:0.20551
# [22]	train-logloss:0.20496	test-logloss:0.19631
# [23]	train-logloss:0.19660	test-logloss:0.18778
# [24]	train-logloss:0.18857	test-logloss:0.17977
# [25]	train-logloss:0.18102	test-logloss:0.17210
# [26]	train-logloss:0.17385	test-logloss:0.16489
# [27]	train-logloss:0.16710	test-logloss:0.15800
# [28]	train-logloss:0.16082	test-logloss:0.15150
# [29]	train-logloss:0.15487	test-logloss:0.14541
# [30]	train-logloss:0.14919	test-logloss:0.13969
# [31]	train-logloss:0.14388	test-logloss:0.13424
# [32]	train-logloss:0.13871	test-logloss:0.12901
# [33]	train-logloss:0.13385	test-logloss:0.12410
# [34]	train-logloss:0.12929	test-logloss:0.11947
# [35]	train-logloss:0.12487	test-logloss:0.11502
# [36]	train-logloss:0.12076	test-logloss:0.11085
# [37]	train-logloss:0.11694	test-logloss:0.10684
# [38]	train-logloss:0.11325	test-logloss:0.10312
# [39]	train-logloss:0.10976	test-logloss:0.09955
# [40]	train-logloss:0.10637	test-logloss:0.09620
# [41]	train-logloss:0.10324	test-logloss:0.09319
# [42]	train-logloss:0.10019	test-logloss:0.09017
# [43]	train-logloss:0.09733	test-logloss:0.08724
# [44]	train-logloss:0.09460	test-logloss:0.08463
# [45]	train-logloss:0.09203	test-logloss:0.08226
# [46]	train-logloss:0.08953	test-logloss:0.07986
# [47]	train-logloss:0.08713	test-logloss:0.07754
# [48]	train-logloss:0.08483	test-logloss:0.07528
# [49]	train-logloss:0.08272	test-logloss:0.07336
# [50]	train-logloss:0.08070	test-logloss:0.07148
# [51]	train-logloss:0.07877	test-logloss:0.06966
# [52]	train-logloss:0.07689	test-logloss:0.06783
# [53]	train-logloss:0.07513	test-logloss:0.06615
# [54]	train-logloss:0.07334	test-logloss:0.06449
# [55]	train-logloss:0.07160	test-logloss:0.06289
# [56]	train-logloss:0.06995	test-logloss:0.06158
# [57]	train-logloss:0.06851	test-logloss:0.06006
# [58]	train-logloss:0.06708	test-logloss:0.05878
# [59]	train-logloss:0.06566	test-logloss:0.05769
# [60]	train-logloss:0.06421	test-logloss:0.05649
# [61]	train-logloss:0.06294	test-logloss:0.05536
# [62]	train-logloss:0.06176	test-logloss:0.05428
# [63]	train-logloss:0.06074	test-logloss:0.05322
# [64]	train-logloss:0.05959	test-logloss:0.05232
# [65]	train-logloss:0.05858	test-logloss:0.05153
# [66]	train-logloss:0.05758	test-logloss:0.05065
# [67]	train-logloss:0.05650	test-logloss:0.04981
# [68]	train-logloss:0.05567	test-logloss:0.04888
# [69]	train-logloss:0.05484	test-logloss:0.04802
# [70]	train-logloss:0.05398	test-logloss:0.04743
# [71]	train-logloss:0.05314	test-logloss:0.04668
# [72]	train-logloss:0.05229	test-logloss:0.04600
# [73]	train-logloss:0.05150	test-logloss:0.04537
# [74]	train-logloss:0.05082	test-logloss:0.04477
# [75]	train-logloss:0.05003	test-logloss:0.04429
# [76]	train-logloss:0.04931	test-logloss:0.04379
# [77]	train-logloss:0.04874	test-logloss:0.04317
# [78]	train-logloss:0.04816	test-logloss:0.04260
# [79]	train-logloss:0.04740	test-logloss:0.04211
# [80]	train-logloss:0.04678	test-logloss:0.04164
# [81]	train-logloss:0.04626	test-logloss:0.04122
# [82]	train-logloss:0.04565	test-logloss:0.04085
# [83]	train-logloss:0.04515	test-logloss:0.04043
# [84]	train-logloss:0.04459	test-logloss:0.04005
# [85]	train-logloss:0.04417	test-logloss:0.03958
# [86]	train-logloss:0.04378	test-logloss:0.03913
# [87]	train-logloss:0.04330	test-logloss:0.03875
# [88]	train-logloss:0.04285	test-logloss:0.03848
# [89]	train-logloss:0.04244	test-logloss:0.03819
# [90]	train-logloss:0.04208	test-logloss:0.03769
# [91]	train-logloss:0.04163	test-logloss:0.03744
# [92]	train-logloss:0.04116	test-logloss:0.03712
# [93]	train-logloss:0.04079	test-logloss:0.03693
# [94]	train-logloss:0.04044	test-logloss:0.03677
# [95]	train-logloss:0.03995	test-logloss:0.03667
# [96]	train-logloss:0.03944	test-logloss:0.03648
# [97]	train-logloss:0.03894	test-logloss:0.03626
# [98]	train-logloss:0.03847	test-logloss:0.03608
# [99]	train-logloss:0.03801	test-logloss:0.03592
# [100]	train-logloss:0.03761	test-logloss:0.03578
# [101]	train-logloss:0.03718	test-logloss:0.03570
# [102]	train-logloss:0.03688	test-logloss:0.03558
# [103]	train-logloss:0.03647	test-logloss:0.03541
# [104]	train-logloss:0.03607	test-logloss:0.03533
# [105]	train-logloss:0.03566	test-logloss:0.03512
# [106]	train-logloss:0.03542	test-logloss:0.03503
# [107]	train-logloss:0.03515	test-logloss:0.03475
# [108]	train-logloss:0.03493	test-logloss:0.03454
# [109]	train-logloss:0.03457	test-logloss:0.03446
# [110]	train-logloss:0.03421	test-logloss:0.03441
# [111]	train-logloss:0.03399	test-logloss:0.03428
# [112]	train-logloss:0.03371	test-logloss:0.03427
# [113]	train-logloss:0.03338	test-logloss:0.03422
# [114]	train-logloss:0.03308	test-logloss:0.03419
# [115]	train-logloss:0.03284	test-logloss:0.03412
# [116]	train-logloss:0.03255	test-logloss:0.03407
# [117]	train-logloss:0.03230	test-logloss:0.03413
# [118]	train-logloss:0.03207	test-logloss:0.03418
# [119]	train-logloss:0.03184	test-logloss:0.03414
# [120]	train-logloss:0.03154	test-logloss:0.03408
# [121]	train-logloss:0.03132	test-logloss:0.03385
# [122]	train-logloss:0.03102	test-logloss:0.03389
# [123]	train-logloss:0.03083	test-logloss:0.03389
# [124]	train-logloss:0.03064	test-logloss:0.03376
# [125]	train-logloss:0.03037	test-logloss:0.03373
# [126]	train-logloss:0.03008	test-logloss:0.03369
# [127]	train-logloss:0.02985	test-logloss:0.03375
# [128]	train-logloss:0.02965	test-logloss:0.03375
# [129]	train-logloss:0.02940	test-logloss:0.03375
# [130]	train-logloss:0.02924	test-logloss:0.03376
# [131]	train-logloss:0.02906	test-logloss:0.03376
# [132]	train-logloss:0.02887	test-logloss:0.03375
# [133]	train-logloss:0.02875	test-logloss:0.03378
# [134]	train-logloss:0.02858	test-logloss:0.03377
# [135]	train-logloss:0.02844	test-logloss:0.03374
# [136]	train-logloss:0.02823	test-logloss:0.03349
# [137]	train-logloss:0.02804	test-logloss:0.03345
# [138]	train-logloss:0.02785	test-logloss:0.03343
# [139]	train-logloss:0.02768	test-logloss:0.03342
# [140]	train-logloss:0.02748	test-logloss:0.03340
# [141]	train-logloss:0.02731	test-logloss:0.03322
# [142]	train-logloss:0.02720	test-logloss:0.03320
# [143]	train-logloss:0.02698	test-logloss:0.03318
# [144]	train-logloss:0.02680	test-logloss:0.03310
# [145]	train-logloss:0.02663	test-logloss:0.03296
# [146]	train-logloss:0.02652	test-logloss:0.03299
# [147]	train-logloss:0.02632	test-logloss:0.03302
# [148]	train-logloss:0.02614	test-logloss:0.03292
# [149]	train-logloss:0.02602	test-logloss:0.03301
# [150]	train-logloss:0.02579	test-logloss:0.03300
# [151]	train-logloss:0.02564	test-logloss:0.03301
# [152]	train-logloss:0.02541	test-logloss:0.03296
# [153]	train-logloss:0.02527	test-logloss:0.03295
# [154]	train-logloss:0.02510	test-logloss:0.03297
# [155]	train-logloss:0.02490	test-logloss:0.03300
# [156]	train-logloss:0.02472	test-logloss:0.03304
# [157]	train-logloss:0.02456	test-logloss:0.03305
# [158]	train-logloss:0.02439	test-logloss:0.03301

# %%
# Make predictions on training and validation data
y_pred_train = clf.predict(dtrain)
y_pred_val = clf.predict(dval)

# %%
# Feature importance analysis using 'gain' method
feat_importance = clf.get_score(importance_type='gain')
feat_importance = {k: v for k, v in sorted(feat_importance.items(), key=lambda item: item[1], reverse=True)}
top_10_gain = list(feat_importance.keys())[:10]

# Feature importance analysis using 'weight' method
feat_importance = clf.get_score(importance_type='weight')
feat_importance = {k: v for k, v in sorted(feat_importance.items(), key=lambda item: item[1], reverse=True)}
top_10_weight = list(feat_importance.keys())[:10]

# Feature importance analysis using SHAP values
explainer = shap.TreeExplainer(clf)
shap_values = explainer(X_train)
shap_summary = pd.DataFrame(shap_values.values, columns=X_train.columns)
mean_abs_shap_values = shap_summary.abs().mean().sort_values(ascending=False)
top_10_shap = mean_abs_shap_values.head(10).index.tolist()

# Combine the top features from each importance analysis method
top_K_feat = set(top_10_gain+top_10_weight+top_10_shap)

# %%
# Save dictionary of best features
with open("./metadata/clf_top_K_feats.pkl", "wb") as f:
    pickle.dump(top_K_feat, f)

# %%
# Plot the SHAP summary plot for the top 10 features
shap.summary_plot(shap_values, X_train,
                   plot_size=(10, 7), max_display=10)

# %%
# plot the histogram of probabilities with the color representing the true label
plt.hist(y_pred_val[y_val==1], bins=50, color='r', alpha=0.5, label='Positive')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.legend(loc='upper center')
plt.show()

# %%
# calculate and plot the AUC-PR curve
precision, recall, _ = precision_recall_curve(y_val, y_pred_val)
average_precision = average_precision_score(y_val, y_pred_val)
plt.plot(recall, precision, label='AP={:.2f}'.format(average_precision))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show()

# %%
# calculate the precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_val, y_pred_val)
area = auc(recall, precision)

# find the threshold that maximizes the AUC-PR
f1_scores = 2 * precision * recall / (precision + recall + 1e-10)
best_threshold = thresholds[np.argmax(f1_scores)]

# print the best threshold and the corresponding AUC-PR
print('Best Threshold: {:.4f}'.format(best_threshold))
# Out:
# Best Threshold: 0.4783

# %%
# Save predictions for the regressor
preds = (y_pred_train >= best_threshold).astype(int)
with open('./output/classifier/y_train1_clf_preds.pkl', 'wb') as f:
    pickle.dump(preds, f)

# Save predictions for the regressor
preds = (y_pred_val >= best_threshold).astype(int)
with open('./output/classifier/y_val1_clf_preds.pkl', 'wb') as f:
    pickle.dump(preds, f)

# %%
# predict binary labels using the best threshold
y_pred = (y_pred_val >= best_threshold).astype(int)

# calculate the confusion matrix
cm = confusion_matrix(y_val, y_pred)

# %%
cm
# Out:
# array([[5279,   17],
#        [  42,  149]], dtype=int64)
