# %%
import pandas as pd
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/train_df_with_labels.csv')
df = df.dropna(subset='Target')

# %%
df.drop(columns=['Date'], inplace=True)

# %%
df = df[df['window_duration']>0]
df = df[df['window_start']==1]

# %%
df.head(2)
# Out:
#       Avg_PLT_CO2VentRate_TPH  Avg_CCS1_WHCO2InjPs_psi  Avg_CCS1_WHCO2InjTp_F  \
# 835                  18333.15                  1133.85                  73.67
# 1095                     0.00                  1080.26                  88.99
#
#       Avg_CCS1_ANPs_psi  Avg_CCS1_DH6325Ps_psi  Avg_CCS1_DH6325Tp_F  \
# 835              515.20                3290.47               113.29
# 1095             762.42                3156.97               115.33
#
#       Avg_VW1_WBTbgPs_psi  Avg_VW1_WBTbgTp_F  Avg_VW1_ANPs_psi  \
# 835               2234.57             104.06              5.46
# 1095              2232.78             104.11              7.23
#
#       Avg_VW1_Z11D4917Ps_psi  ...  Avg_VW1_Z02D6982Tp_F  \
# 835                  2073.54  ...                121.10
# 1095                 2073.41  ...                121.22
#
#       Avg_VW1_Z01D7061Ps_psi  Avg_VW1_Z01D7061Tp_F  Avg_VW1_Z0910D5482Ps_psi  \
# 835                  3221.17                122.44                   2421.57
# 1095                 3221.71                122.53                   2401.29
#
#       Avg_VW1_Z0910D5482Tp_F  Target  Abs Target  window_start  \
# 835                   112.22 4000.00       45.70             1
# 1095                  112.33    5.06        5.06             1
#
#       window_duration  within_window
# 835                 4              1
# 1095               22              1
#
# [2 rows x 38 columns]

# %%
y = df['Target']
x = df.drop(['window_duration','Target','Abs Target','window_start','within_window'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=123)

# %%
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)

# %%
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:09<00:00,  4.50it/s]
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# RandomForestRegressor                       -0.39       0.32   13.84
# AdaBoostRegressor                           -0.40       0.31   13.87
# GradientBoostingRegressor                   -0.42       0.30   14.01
# ExtraTreesRegressor                         -0.44       0.29   14.07
# BaggingRegressor                            -0.48       0.27   14.30
# XGBRegressor                                -0.53       0.24   14.54
# LassoLarsCV                                 -0.98       0.02   16.54
# Lasso                                       -1.00       0.02   16.59
# OrthogonalMatchingPursuitCV                 -1.02       0.01   16.67
# LassoLars                                   -1.02       0.01   16.68
# OrthogonalMatchingPursuit                   -1.03       0.00   16.72
# NuSVR                                       -1.04      -0.00   16.75
# QuantileRegressor                           -1.04      -0.00   16.77
# KNeighborsRegressor                         -1.05      -0.01   16.81
# LarsCV                                      -1.08      -0.02   16.93
# SVR                                         -1.09      -0.03   16.97
# LassoCV                                     -1.12      -0.04   17.10
# SGDRegressor                                -1.19      -0.08   17.37
# HuberRegressor                              -1.24      -0.10   17.57
# LassoLarsIC                                 -1.28      -0.12   17.72
# LinearSVR                                   -1.29      -0.13   17.76
# BayesianRidge                               -1.30      -0.13   17.82
# RidgeCV                                     -1.30      -0.13   17.82
# Ridge                                       -1.32      -0.14   17.87
# MLPRegressor                                -1.40      -0.18   18.19
# LinearRegression                            -1.41      -0.19   18.22
# TransformedTargetRegressor                  -1.41      -0.19   18.22
# ElasticNetCV                                -1.51      -0.24   18.61
# KernelRidge                                 -1.66      -0.31   19.14
# PassiveAggressiveRegressor                  -1.78      -0.37   19.58
# DecisionTreeRegressor                       -1.85      -0.40   19.83
# ElasticNet                                  -1.88      -0.42   19.92
# ExtraTreeRegressor                          -2.39      -0.67   21.62
# TweedieRegressor                            -2.41      -0.68   21.67
# DummyRegressor                              -2.46      -0.71   21.85
# LGBMRegressor                               -4.11      -1.51   26.53
# HistGradientBoostingRegressor               -4.13      -1.53   26.59
# GaussianProcessRegressor                   -16.95      -7.84   49.74
# Lars                                      -407.76    -200.23  237.33
# RANSACRegressor                        -375815.70 -185016.45 7196.20
#
#                                Time Taken
# Model
# RandomForestRegressor                0.49
# AdaBoostRegressor                    0.13
# GradientBoostingRegressor            0.23
# ExtraTreesRegressor                  0.31
# BaggingRegressor                     0.06
# XGBRegressor                         0.57
# LassoLarsCV                          0.08
# Lasso                                0.01
# OrthogonalMatchingPursuitCV          0.01
# LassoLars                            0.01
# OrthogonalMatchingPursuit            0.01
# NuSVR                                0.02
# QuantileRegressor                    4.37
# KNeighborsRegressor                  0.39
# LarsCV                               0.05
# SVR                                  0.02
# LassoCV                              0.11
# SGDRegressor                         0.02
# HuberRegressor                       0.07
# LassoLarsIC                          0.02
# LinearSVR                            0.02
# BayesianRidge                        0.01
# RidgeCV                              0.03
# Ridge                                0.01
# MLPRegressor                         0.58
# LinearRegression                     0.01
# TransformedTargetRegressor           0.01
# ElasticNetCV                         0.09
# KernelRidge                          0.02
# PassiveAggressiveRegressor           0.01
# DecisionTreeRegressor                0.02
# ElasticNet                           0.01
# ExtraTreeRegressor                   0.01
# TweedieRegressor                     0.02
# DummyRegressor                       0.01
# LGBMRegressor                        0.17
# HistGradientBoostingRegressor        1.07
# GaussianProcessRegressor             0.03
# Lars                                 0.02
# RANSACRegressor                      0.15
