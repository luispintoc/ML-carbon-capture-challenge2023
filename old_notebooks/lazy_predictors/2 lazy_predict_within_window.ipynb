# %%
import pandas as pd
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/train_df_with_labels.csv')
df = df.dropna(subset='Target')

# %%
df.drop(columns=['Date', 'Target', 'Abs Target', 'window_start', 'window_duration'], inplace=True)

# %%
y = df['within_window']
x = df.drop(['within_window'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=123)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)

# %%
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [02:18<00:00,  4.78s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# DecisionTreeClassifier             0.97               0.80     0.80      0.96
# XGBClassifier                      0.97               0.79     0.79      0.97
# RandomForestClassifier             0.97               0.78     0.78      0.97
# LGBMClassifier                     0.97               0.78     0.78      0.97
# ExtraTreesClassifier               0.97               0.78     0.78      0.97
# BaggingClassifier                  0.97               0.77     0.77      0.97
# ExtraTreeClassifier                0.95               0.76     0.76      0.95
# KNeighborsClassifier               0.96               0.70     0.70      0.96
# QuadraticDiscriminantAnalysis      0.81               0.68     0.68      0.85
# LabelPropagation                   0.96               0.63     0.63      0.94
# LabelSpreading                     0.96               0.62     0.62      0.94
# AdaBoostClassifier                 0.95               0.62     0.62      0.94
# BernoulliNB                        0.90               0.58     0.58      0.90
# NearestCentroid                    0.73               0.53     0.53      0.80
# GaussianNB                         0.92               0.52     0.52      0.91
# PassiveAggressiveClassifier        0.89               0.51     0.51      0.89
# CalibratedClassifierCV             0.94               0.51     0.51      0.92
# RidgeClassifier                    0.94               0.50     0.50      0.92
# RidgeClassifierCV                  0.94               0.50     0.50      0.92
# SGDClassifier                      0.94               0.50     0.50      0.92
# LinearDiscriminantAnalysis         0.94               0.50     0.50      0.92
# LogisticRegression                 0.94               0.50     0.50      0.92
# LinearSVC                          0.94               0.50     0.50      0.92
# DummyClassifier                    0.94               0.50     0.50      0.92
# SVC                                0.94               0.50     0.50      0.92
# Perceptron                         0.93               0.50     0.50      0.91
#
#                                Time Taken
# Model
# DecisionTreeClassifier               1.21
# XGBClassifier                        3.53
# RandomForestClassifier               8.55
# LGBMClassifier                       0.87
# ExtraTreesClassifier                 2.94
# BaggingClassifier                    7.45
# ExtraTreeClassifier                  0.09
# KNeighborsClassifier                 1.04
# QuadraticDiscriminantAnalysis        0.11
# LabelPropagation                    32.05
# LabelSpreading                      38.19
# AdaBoostClassifier                   4.60
# BernoulliNB                          0.12
# NearestCentroid                      0.06
# GaussianNB                           0.08
# PassiveAggressiveClassifier          0.08
# CalibratedClassifierCV              22.61
# RidgeClassifier                      0.09
# RidgeClassifierCV                    0.13
# SGDClassifier                        0.19
# LinearDiscriminantAnalysis           0.20
# LogisticRegression                   0.26
# LinearSVC                            5.04
# DummyClassifier                      0.06
# SVC                                  8.86
# Perceptron                           0.09
