# %% [markdown]
# Problem Statement
#
# This challenge aims to use time series injection information and monitoring data on a carbon capture well to predict carbon capture well injection rates deltas. Correlating the change in injection rate to the behavior of other parameters in the well can be used to provide a checkpoint against carbon migration from the well or other losses during the process.  The code developed to predict injection rate deltas based on monitoring well data can be used to validate carbon containment throughout the injection of the well.

# %%
# Using AI to Validate Carbon Containment in the Illinois Basin

## Importing Libraries

### First, we will import the necessary Python libraries, such as pandas, numpy, and scikit-learn.

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Loading and Preprocessing Data
#
# Load the dataset and perform some basic preprocessing steps. This includes removing any missing values, converting categorical variables into one-hot encoded format, and scaling the data using StandardScaler.

# %%
# Load the dataset
data = pd.read_csv('./data/OLD_illinois_basing_train.csv')

# Drop any rows with missing values
# data.dropna(inplace=True)

# Convert categorical variables into one-hot encoded format
# data = pd.get_dummies(data, columns=['categorical_var1', 'categorical_var2'])

# %%
data.shape
# Out:
# (27398, 36)

# %%
data.isna().sum()
# Out:
# SampleTimeUTC                  0
# Avg_PLT_CO2InjRate_TPH         0
# Avg_PLT_CO2VentRate_TPH        0
# Avg_CCS1_WHCO2InjPs_psi      128
# Avg_CCS1_WHCO2InjTp_F          0
# Avg_CCS1_ANPs_psi             94
# Avg_CCS1_DH6325Ps_psi          0
# Avg_CCS1_DH6325Tp_F            0
# Avg_VW1_WBTbgPs_psi         1271
# Avg_VW1_WBTbgTp_F           1337
# Avg_VW1_ANPs_psi            3911
# Avg_VW1_Z11D4917Ps_psi       710
# Avg_VW1_Z11D4917Tp_F         689
# Avg_VW1_Z10D5001Ps_psi       710
# Avg_VW1_Z10D5001Tp_F         689
# Avg_VW1_Z09D5653Ps_psi       710
# Avg_VW1_Z09D5653Tp_F         689
# Avg_VW1_Z08D5840Ps_psi      1209
# Avg_VW1_Z08D5840Tp_F        1520
# Avg_VW1_Z07D6416Ps_psi      1413
# Avg_VW1_Z07D6416Tp_F        1413
# Avg_VW1_Z06D6632Ps_psi      1898
# Avg_VW1_Z06D6632Tp_F        1898
# Avg_VW1_Z05D6720Ps_psi      3443
# Avg_VW1_Z05D6720Tp_F        3443
# Avg_VW1_Z04D6837Ps_psi       798
# Avg_VW1_Z04D6837Tp_F         798
# Avg_VW1_Z03D6945Ps_psi      3037
# ...

# %%
data['inj_rate_test'] = data['Avg_PLT_CO2InjRate_TPH'].diff()

# %%
plt.plot(data['inj_rate_test'], 'ko')

# %%
plt.plot(data['Avg_PLT_CO2InjRate_TPH'], 'ko')

# %%
import matplotlib.pyplot as plt

# %%
for f in data.columns:
    if 'SampleTimeUTC' in f:
        continue
    else:
        plt.plot(data[f], 'ko')
        # plt.plot(data_test)
        plt.title(f)
        plt.show()

# %%
plt.plot(data[(data[data.columns[-1]]>-2000)&(data[data.columns[-1]]<2500)][data.columns[-1]], 'ro')

# %%
plt.plot(x['Date'], x['Average'].replace(to_replace=r'[^0-9]', value=0, regex=True), 'ko')

# %%
x = df[(df['Date']>=pd.to_datetime('2009-10-01'))&(df['Date']<=pd.to_datetime('2012-11-14'))]

# %%
plt.plot(df[(df['Date']>=pd.to_datetime('2009-10-01'))&(df['Date']<=pd.to_datetime('2012-11-14'))]['Maximum'].replace(to_replace=r'[^0-9]', value=0, regex=True), 'ko')

# %%
list(df[(df['Date']>=pd.to_datetime('2009-10-01'))&(df['Date']<=pd.to_datetime('2012-11-14'))]['Date'])
# Out:
# [Timestamp('2009-10-01 00:00:00'),
#  Timestamp('2009-10-02 00:00:00'),
#  Timestamp('2009-10-03 00:00:00'),
#  Timestamp('2009-10-04 00:00:00'),
#  Timestamp('2009-10-05 00:00:00'),
#  Timestamp('2009-10-06 00:00:00'),
#  Timestamp('2009-10-07 00:00:00'),
#  Timestamp('2009-10-08 00:00:00'),
#  Timestamp('2009-10-09 00:00:00'),
#  Timestamp('2009-10-10 00:00:00'),
#  Timestamp('2009-10-11 00:00:00'),
#  Timestamp('2009-10-12 00:00:00'),
#  Timestamp('2009-10-13 00:00:00'),
#  Timestamp('2009-10-14 00:00:00'),
#  Timestamp('2009-10-15 00:00:00'),
#  Timestamp('2009-10-16 00:00:00'),
#  Timestamp('2009-10-17 00:00:00'),
#  Timestamp('2009-10-18 00:00:00'),
#  Timestamp('2009-10-19 00:00:00'),
#  Timestamp('2009-10-20 00:00:00'),
#  Timestamp('2009-10-21 00:00:00'),
#  Timestamp('2009-10-22 00:00:00'),
#  Timestamp('2009-10-23 00:00:00'),
#  Timestamp('2009-10-24 00:00:00'),
#  Timestamp('2009-10-25 00:00:00'),
#  Timestamp('2009-10-26 00:00:00'),
#  Timestamp('2009-10-27 00:00:00'),
# ...

# %%
df['Date']

# %%
data['SampleTimeUTC'].max()
# Out:
# '2012-11-14 9:00:00'

# %%
df = pd.read_excel('./data/Decatur weather.xlsx')

# %%
df.sort_values('Date', inplace=True)

# %%
data['Avg_CCS1_WHCO2InjPs_psi'].plot()
# Out:
# <AxesSubplot:>

# %%
data['SampleTimeUTC'].min()
# Out:
# '2009-10-01 10:00:00'

# %%
data['SampleTimeUTC'].max()
# Out:
# '2012-11-26 9:00:00'

# %%
# OLD dataset
data['Avg_PLT_CO2InjRate_TPH'][1000:].plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_excel('./data/Decatur weather.xlsx')

# %%
df.sort_values('Date', inplace=True)

# %%
df['Average'].replace(to_replace=r'[^0-9]', value=0, regex=True).plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#            Date Maximum Minimum Average Departure HDD CDD Precipitation  \
# 2008 2009-09-01      74      52      63      -8.9   2   0             0
# 2009 2009-09-02      76      52      64      -7.7   1   0             0
# 2010 2009-09-03      81      57      69      -2.4   0   4             0
# 2011 2009-09-04      81      61      71      -0.2   0   6             0
# 2012 2009-09-05      75      64    69.5      -1.4   0   5          0.13
# ...         ...     ...     ...     ...       ...  ..  ..           ...
# 2003 2016-06-26      93      73      83       8.1   0  18             0
# 2004 2016-06-27      90      69    79.5       4.5   0  15             0
# 2005 2016-06-28      80      63    71.5      -3.6   0   7             0
# 2006 2016-06-29      78      54      66      -9.2   0   1             0
# 2007 2016-06-30      78      59    68.5      -6.8   0   4             0
#
#      New Snow Snow Depth
# 2008        0          0
# 2009        0          0
# ...

# %%
data['inj_diff\xa0'].hist(log=True)
# Out:
# <AxesSubplot:>

# %%
data[['Avg_PLT_CO2InjRate_TPH','inj_diff\xa0']]
# Out:
#        Avg_PLT_CO2InjRate_TPH  inj_diff
# 1                    0.000000   0.000000
# 2                    0.000000   0.000000
# 3                    0.000000   0.000000
# 4                    0.000000   0.000000
# 5                    0.000000   0.000000
# ...                       ...        ...
# 27305               45.620833  -0.122917
# 27306               45.546528  -0.074305
# 27307               45.639930   0.093403
# 27308               45.702430   0.062500
# 27309               45.633681  -0.068749
#
# [15637 rows x 2 columns]

# %% [markdown]
# Exploratory Data Analysis
#
# Explore the data to gain insights into its structure and characteristics. Generate visualizations to help identify any patterns or trends in the data.

# %%
import matplotlib.pyplot as plt

# Generate histograms of each feature
data.hist(bins=20, figsize=(20, 20))
plt.show()

# Generate a scatter plot of features
plt.scatter(data['feature1'], data['feature2'])
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# Feature Selection
#
# Use correlation analysis to identify the most important features for the machine learning model. This will help to improve the accuracy of predictions and reduce the risk of overfitting

# %%
# Compute correlation matrix
corr_matrix = data.corr()

# Generate heatmap of correlation matrix
import seaborn as sns
sns.heatmap(corr_matrix)
plt.show()

# Select the most correlated features
corr_threshold = 0.5
corr_pairs = np.where(np.abs(corr_matrix) > corr_threshold)
corr_pairs = [(corr_matrix.iloc[i, j], i, j) for i, j in zip(*corr_pairs) if i != j and i < j]
corr_pairs.sort(reverse=True)

# %% [markdown]
# Model Development
#
# Split the data using the preprocessed data. Split the dataset into training and testing sets. This will allow to evaluate the performance of the machine learning model on unseen data.

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data[data.columns[:-1]], data['target'], test_size=0.2, random_state=42)

# Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Model Selection and Tuning
#
# Experiment different machine learning algorithms, such as logistic regression, decision trees, and random forests, and tune the hyperparameters of each model to find the best combination for the task at hand.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Define the model
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# Evaluate the model on the test set
y_pred = model.predict(X_test_scaled)
test_accuracy = accuracy_score(y_test, y_pred)
print("Test accuracy: ", test_accuracy)

# Define hyperparameters to tune
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2', 'elasticnet'], 'solver': ['lbfgs', 'liblinear', 'saga']}

# Define grid search
grid = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)

# Fit the grid search
grid.fit(X_train_scaled, y_train)

# Print best hyperparameters
print("Best hyperparameters:", grid.best_params_)

# Retrain the model with best hyperparameters
model_tuned = LogisticRegression(C=10, penalty='l2', solver='liblinear')
model_tuned.fit(X_train_scaled, y_train)

# Make predictions on testing set
y_pred_tuned = logreg_tuned.predict(X_test_scaled)

# Calculate accuracy
accuracy_tuned = accuracy_score(y_test, y_pred_tuned)
print("Tuned Accuracy:", accuracy_tuned)

# %% [markdown]
# Submission
#
# Once the machine learning model is developed and evaluated, contestants submit the ML code to an SPEMLChallenge@gmail.com.  The results are submitted to the XEEK.org platform for preliminary scoring.
