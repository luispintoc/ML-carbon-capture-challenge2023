# %%
from sklearnex import patch_sklearn
patch_sklearn()

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import auc, precision_recall_curve, average_precision_score, confusion_matrix
import xgboost as xgb
import numpy as np
import pickle
import shap
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (10,7)
plt.rcParams.update({'font.size': 15})
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# Read the train dataset from the CSV file
train_set = pd.read_csv('../data/train_df_expanded_KNN_imp_feats.csv')
# Replace infinite values with NaN
train_set = train_set.replace([np.inf, -np.inf], np.nan)

# %%
train_set['Target > 1'] = train_set['Abs Target'].apply(lambda x: 1 if x > 1 else 0)

# %%
# Extract the target variable from the dataset
y_train = train_set['Target > 1']
# Drop unnecessary columns and keep the feature matrix
x_train = train_set.drop(['Date', 'Target', 'Abs Target', 'Target > 1', 'Target > 2'], axis=1)

# %%
# Split the data into training, validation, and test sets using a 60-20-20 split
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.4, shuffle=False)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, shuffle=False)

# Drop the first 5 rows of validation set to avoid leakage from lagged features
X_val = X_val.iloc[5:]
y_val = y_val.iloc[5:]

# Create XGBoost DMatrix objects for training and validation data
dtrain = xgb.DMatrix(X_train, y_train)
dval = xgb.DMatrix(X_val, y_val)

# %%
# Define the hyperparameters for the XGBoost model
params = {'alpha': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'eta': 0.05, 'eval_metric': ['logloss'],
          'lambda': 1, 'max_depth': 4, 'objective': 'binary:logistic', 'scale_pos_weight': 1, 'subsample': 0.7, 'tree_method': 'exact',
          'nthread': -2}

# Train the XGBoost model
clf = xgb.train(params,dtrain,evals=[(dtrain, 'train'),(dval, 'test')],num_boost_round=300,verbose_eval=True,early_stopping_rounds=10)
# Out:
# [0]	train-logloss:0.65028	test-logloss:0.64872
# [1]	train-logloss:0.61145	test-logloss:0.60838
# [2]	train-logloss:0.57623	test-logloss:0.57177
# [3]	train-logloss:0.54401	test-logloss:0.53834
# [4]	train-logloss:0.51438	test-logloss:0.50723
# [5]	train-logloss:0.48721	test-logloss:0.47840
# [6]	train-logloss:0.46204	test-logloss:0.45218
# [7]	train-logloss:0.43897	test-logloss:0.42792
# [8]	train-logloss:0.41743	test-logloss:0.40533
# [9]	train-logloss:0.39751	test-logloss:0.38452
# [10]	train-logloss:0.37902	test-logloss:0.36512
# [11]	train-logloss:0.36186	test-logloss:0.34731
# [12]	train-logloss:0.34585	test-logloss:0.33050
# [13]	train-logloss:0.33107	test-logloss:0.31500
# [14]	train-logloss:0.31716	test-logloss:0.30007
# [15]	train-logloss:0.30412	test-logloss:0.28613
# [16]	train-logloss:0.29189	test-logloss:0.27329
# [17]	train-logloss:0.28046	test-logloss:0.26110
# [18]	train-logloss:0.26967	test-logloss:0.25029
# [19]	train-logloss:0.25957	test-logloss:0.24004
# [20]	train-logloss:0.25012	test-logloss:0.22992
# [21]	train-logloss:0.24115	test-logloss:0.22042
# [22]	train-logloss:0.23259	test-logloss:0.21155
# [23]	train-logloss:0.22463	test-logloss:0.20332
# [24]	train-logloss:0.21705	test-logloss:0.19527
# [25]	train-logloss:0.20993	test-logloss:0.18756
# [26]	train-logloss:0.20324	test-logloss:0.18041
# [27]	train-logloss:0.19694	test-logloss:0.17377
# [28]	train-logloss:0.19107	test-logloss:0.16763
# [29]	train-logloss:0.18536	test-logloss:0.16153
# [30]	train-logloss:0.17996	test-logloss:0.15594
# [31]	train-logloss:0.17490	test-logloss:0.15054
# [32]	train-logloss:0.17004	test-logloss:0.14576
# [33]	train-logloss:0.16548	test-logloss:0.14115
# [34]	train-logloss:0.16121	test-logloss:0.13681
# [35]	train-logloss:0.15705	test-logloss:0.13479
# [36]	train-logloss:0.15317	test-logloss:0.13089
# [37]	train-logloss:0.14951	test-logloss:0.12694
# [38]	train-logloss:0.14596	test-logloss:0.12325
# [39]	train-logloss:0.14261	test-logloss:0.11990
# [40]	train-logloss:0.13946	test-logloss:0.11668
# [41]	train-logloss:0.13643	test-logloss:0.11348
# [42]	train-logloss:0.13352	test-logloss:0.11070
# [43]	train-logloss:0.13073	test-logloss:0.10772
# [44]	train-logloss:0.12806	test-logloss:0.10489
# [45]	train-logloss:0.12552	test-logloss:0.10255
# [46]	train-logloss:0.12309	test-logloss:0.09961
# [47]	train-logloss:0.12065	test-logloss:0.09735
# [48]	train-logloss:0.11853	test-logloss:0.09548
# [49]	train-logloss:0.11647	test-logloss:0.09321
# [50]	train-logloss:0.11454	test-logloss:0.09111
# [51]	train-logloss:0.11260	test-logloss:0.08901
# [52]	train-logloss:0.11074	test-logloss:0.08700
# [53]	train-logloss:0.10880	test-logloss:0.08554
# [54]	train-logloss:0.10713	test-logloss:0.08375
# [55]	train-logloss:0.10550	test-logloss:0.08216
# [56]	train-logloss:0.10400	test-logloss:0.08060
# [57]	train-logloss:0.10262	test-logloss:0.07931
# [58]	train-logloss:0.10134	test-logloss:0.07917
# [59]	train-logloss:0.10010	test-logloss:0.07789
# [60]	train-logloss:0.09881	test-logloss:0.07694
# [61]	train-logloss:0.09750	test-logloss:0.07578
# [62]	train-logloss:0.09632	test-logloss:0.07513
# [63]	train-logloss:0.09511	test-logloss:0.07553
# [64]	train-logloss:0.09402	test-logloss:0.07438
# [65]	train-logloss:0.09279	test-logloss:0.07291
# [66]	train-logloss:0.09178	test-logloss:0.07218
# [67]	train-logloss:0.09060	test-logloss:0.07155
# [68]	train-logloss:0.08975	test-logloss:0.07048
# [69]	train-logloss:0.08877	test-logloss:0.07053
# [70]	train-logloss:0.08786	test-logloss:0.06980
# [71]	train-logloss:0.08697	test-logloss:0.06889
# [72]	train-logloss:0.08612	test-logloss:0.06810
# [73]	train-logloss:0.08549	test-logloss:0.06734
# [74]	train-logloss:0.08476	test-logloss:0.06669
# [75]	train-logloss:0.08395	test-logloss:0.06592
# [76]	train-logloss:0.08334	test-logloss:0.06609
# [77]	train-logloss:0.08270	test-logloss:0.06585
# [78]	train-logloss:0.08212	test-logloss:0.06545
# [79]	train-logloss:0.08140	test-logloss:0.06478
# [80]	train-logloss:0.08056	test-logloss:0.06422
# [81]	train-logloss:0.08002	test-logloss:0.06361
# [82]	train-logloss:0.07955	test-logloss:0.06294
# [83]	train-logloss:0.07909	test-logloss:0.06234
# [84]	train-logloss:0.07849	test-logloss:0.06196
# [85]	train-logloss:0.07794	test-logloss:0.06135
# [86]	train-logloss:0.07743	test-logloss:0.06096
# [87]	train-logloss:0.07696	test-logloss:0.06065
# [88]	train-logloss:0.07649	test-logloss:0.06036
# [89]	train-logloss:0.07602	test-logloss:0.05990
# [90]	train-logloss:0.07538	test-logloss:0.05925
# [91]	train-logloss:0.07492	test-logloss:0.05861
# [92]	train-logloss:0.07436	test-logloss:0.05826
# [93]	train-logloss:0.07370	test-logloss:0.05810
# [94]	train-logloss:0.07309	test-logloss:0.05782
# [95]	train-logloss:0.07257	test-logloss:0.05791
# [96]	train-logloss:0.07204	test-logloss:0.05764
# [97]	train-logloss:0.07164	test-logloss:0.05744
# [98]	train-logloss:0.07112	test-logloss:0.05722
# [99]	train-logloss:0.07067	test-logloss:0.05689
# [100]	train-logloss:0.07005	test-logloss:0.05646
# [101]	train-logloss:0.06972	test-logloss:0.05626
# [102]	train-logloss:0.06922	test-logloss:0.05599
# [103]	train-logloss:0.06879	test-logloss:0.05589
# [104]	train-logloss:0.06847	test-logloss:0.05575
# [105]	train-logloss:0.06808	test-logloss:0.05541
# [106]	train-logloss:0.06767	test-logloss:0.05532
# [107]	train-logloss:0.06714	test-logloss:0.05514
# [108]	train-logloss:0.06679	test-logloss:0.05468
# [109]	train-logloss:0.06632	test-logloss:0.05449
# [110]	train-logloss:0.06591	test-logloss:0.05417
# [111]	train-logloss:0.06559	test-logloss:0.05410
# [112]	train-logloss:0.06531	test-logloss:0.05408
# [113]	train-logloss:0.06492	test-logloss:0.05411
# [114]	train-logloss:0.06465	test-logloss:0.05389
# [115]	train-logloss:0.06429	test-logloss:0.05362
# [116]	train-logloss:0.06405	test-logloss:0.05353
# [117]	train-logloss:0.06382	test-logloss:0.05324
# [118]	train-logloss:0.06360	test-logloss:0.05332
# [119]	train-logloss:0.06320	test-logloss:0.05331
# [120]	train-logloss:0.06278	test-logloss:0.05324
# [121]	train-logloss:0.06248	test-logloss:0.05313
# [122]	train-logloss:0.06212	test-logloss:0.05293
# [123]	train-logloss:0.06177	test-logloss:0.05283
# [124]	train-logloss:0.06145	test-logloss:0.05284
# [125]	train-logloss:0.06116	test-logloss:0.05276
# [126]	train-logloss:0.06078	test-logloss:0.05267
# [127]	train-logloss:0.06057	test-logloss:0.05257
# [128]	train-logloss:0.06030	test-logloss:0.05253
# [129]	train-logloss:0.05990	test-logloss:0.05253
# [130]	train-logloss:0.05967	test-logloss:0.05246
# [131]	train-logloss:0.05941	test-logloss:0.05244
# [132]	train-logloss:0.05904	test-logloss:0.05245
# [133]	train-logloss:0.05873	test-logloss:0.05245
# [134]	train-logloss:0.05849	test-logloss:0.05245
# [135]	train-logloss:0.05812	test-logloss:0.05244
# [136]	train-logloss:0.05791	test-logloss:0.05245
# [137]	train-logloss:0.05777	test-logloss:0.05246
# [138]	train-logloss:0.05749	test-logloss:0.05242
# [139]	train-logloss:0.05718	test-logloss:0.05243
# [140]	train-logloss:0.05685	test-logloss:0.05249
# [141]	train-logloss:0.05655	test-logloss:0.05241
# [142]	train-logloss:0.05628	test-logloss:0.05235
# [143]	train-logloss:0.05608	test-logloss:0.05231
# [144]	train-logloss:0.05584	test-logloss:0.05235
# [145]	train-logloss:0.05552	test-logloss:0.05232
# [146]	train-logloss:0.05522	test-logloss:0.05233
# [147]	train-logloss:0.05489	test-logloss:0.05237
# [148]	train-logloss:0.05466	test-logloss:0.05213
# [149]	train-logloss:0.05446	test-logloss:0.05225
# [150]	train-logloss:0.05432	test-logloss:0.05205
# [151]	train-logloss:0.05414	test-logloss:0.05208
# [152]	train-logloss:0.05389	test-logloss:0.05200
# [153]	train-logloss:0.05359	test-logloss:0.05200
# [154]	train-logloss:0.05335	test-logloss:0.05206
# [155]	train-logloss:0.05318	test-logloss:0.05194
# [156]	train-logloss:0.05290	test-logloss:0.05176
# [157]	train-logloss:0.05261	test-logloss:0.05173
# [158]	train-logloss:0.05235	test-logloss:0.05174
# [159]	train-logloss:0.05208	test-logloss:0.05171
# [160]	train-logloss:0.05180	test-logloss:0.05170
# [161]	train-logloss:0.05158	test-logloss:0.05171
# [162]	train-logloss:0.05138	test-logloss:0.05160
# [163]	train-logloss:0.05110	test-logloss:0.05155
# [164]	train-logloss:0.05080	test-logloss:0.05151
# [165]	train-logloss:0.05057	test-logloss:0.05154
# [166]	train-logloss:0.05029	test-logloss:0.05155
# [167]	train-logloss:0.05007	test-logloss:0.05158
# [168]	train-logloss:0.04980	test-logloss:0.05167
# [169]	train-logloss:0.04962	test-logloss:0.05169
# [170]	train-logloss:0.04946	test-logloss:0.05162
# [171]	train-logloss:0.04924	test-logloss:0.05172
# [172]	train-logloss:0.04906	test-logloss:0.05182
# [173]	train-logloss:0.04883	test-logloss:0.05184
# [174]	train-logloss:0.04864	test-logloss:0.05180

# %%
# Make predictions on training and validation data
y_pred_train = clf.predict(dtrain)
y_pred_val = clf.predict(dval)

# %%
# Feature importance analysis using 'gain' method
feat_importance = clf.get_score(importance_type='gain')
feat_importance = {k: v for k, v in sorted(feat_importance.items(), key=lambda item: item[1], reverse=True)}
top_10_gain = list(feat_importance.keys())[:10]

# Feature importance analysis using 'weight' method
feat_importance = clf.get_score(importance_type='weight')
feat_importance = {k: v for k, v in sorted(feat_importance.items(), key=lambda item: item[1], reverse=True)}
top_10_weight = list(feat_importance.keys())[:10]

# Feature importance analysis using SHAP values
explainer = shap.TreeExplainer(clf)
shap_values = explainer(X_train)
shap_summary = pd.DataFrame(shap_values.values, columns=X_train.columns)
mean_abs_shap_values = shap_summary.abs().mean().sort_values(ascending=False)
top_10_shap = mean_abs_shap_values.head(10).index.tolist()

# Combine the top features from each importance analysis method
top_K_feat = set(top_10_gain+top_10_weight+top_10_shap)

# %%
# Save dictionary of best features
with open("./clf_top_K_feat_plusMinus1.pkl", "wb") as f:
    pickle.dump(top_K_feat, f)

# %%
# Plot the SHAP summary plot for the top 10 features
shap.summary_plot(shap_values, X_train,
                   plot_size=(10, 7), max_display=10)

# %%
# plot the histogram of probabilities with the color representing the true label
plt.hist(y_pred_val[y_val==1], bins=50, color='r', alpha=0.5, label='Positive')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.legend(loc='upper center')
plt.show()

# %%
# calculate and plot the AUC-PR curve
precision, recall, _ = precision_recall_curve(y_val, y_pred_val)
average_precision = average_precision_score(y_val, y_pred_val)
plt.plot(recall, precision, label='AP={:.2f}'.format(average_precision))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show()

# %%
# calculate the precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_val, y_pred_val)
area = auc(recall, precision)

# find the threshold that maximizes the AUC-PR
f1_scores = 2 * precision * recall / (precision + recall + 1e-10)
best_threshold = thresholds[np.argmax(f1_scores)]

# print the best threshold and the corresponding AUC-PR
print('Best Threshold: {:.4f}'.format(best_threshold))
# Out:
# Best Threshold: 0.3386

# %%
# predict binary labels using the best threshold
y_pred = (y_pred_val >= best_threshold).astype(int)

# calculate the confusion matrix
cm = confusion_matrix(y_val, y_pred)

# %%
cm
# Out:
# array([[5212,   29],
#        [  57,  189]], dtype=int64)
